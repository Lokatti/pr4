# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


df = pd.read_csv('vgsales_2.csv')
df
# Out:
#       Rank                                      Name Platform    Year
# 0    12200  Cabela's Big Game Hunter 2005 Adventures       GC  2004.0  \
# 1    10814           Minority Report: Everybody Runs       XB  2002.0
# 2      894                      Mario Super Sluggers      Wii  2008.0
# 3     4808              Warriors Orochi 2 (JP sales)      PS2  2008.0
# 4    13925                    Don Bradman Cricket 14     XOne  2015.0
# ..     ...                                       ...      ...     ...
# 548   4143                           SimCity Creator      Wii  2008.0
# 549  14462                             Freaky Flyers       XB  2003.0
# 550   7513                                Frogger 3D      3DS  2011.0
# 551    872           Tom Clancy's Rainbow Six: Vegas     X360  2006.0
# 552  16389                          TrackMania Turbo       PC  2016.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          553 non-null    int64
#  1   Name          553 non-null    object
#  2   Platform      553 non-null    object
#  3   Year          546 non-null    float64
#  4   Genre         553 non-null    object
#  5   Publisher     549 non-null    object
#  6   NA_Sales      553 non-null    float64
#  7   EU_Sales      553 non-null    float64
#  8   JP_Sales      553 non-null    float64
#  9   Other_Sales   553 non-null    float64
#  10  Global_Sales  553 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 47.6+ KB

# %%
df.describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales
# count    553.000000   546.000000  553.000000  553.000000  553.000000  \
# mean    7892.754069  2006.243590    0.264051    0.150470    0.084864
# std     4907.196792     6.031812    0.661083    0.434039    0.235014
# min       24.000000  1981.000000    0.000000    0.000000    0.000000
# 25%     3628.000000  2003.000000    0.000000    0.000000    0.000000
# 50%     7515.000000  2007.000000    0.070000    0.020000    0.000000
# 75%    12221.000000  2010.000000    0.280000    0.150000    0.050000
# max    16574.000000  2017.000000    9.630000    5.310000    2.430000
#
#        Other_Sales  Global_Sales
# count   553.000000    553.000000
# mean      0.043671      0.543490
# std       0.114452      1.214904
# min       0.000000      0.010000
# 25%       0.000000      0.070000
# 50%       0.010000      0.200000
# 75%       0.040000      0.560000
# max       1.380000     16.380000

# %%
df.shape
# Out:
# (553, 11)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            7
# Genre           0
# Publisher       4
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df1 = df.drop(columns=['EU_Sales'])
df1
# Out:
#       Rank                                      Name Platform    Year
# 0    12200  Cabela's Big Game Hunter 2005 Adventures       GC  2004.0  \
# 1    10814           Minority Report: Everybody Runs       XB  2002.0
# 2      894                      Mario Super Sluggers      Wii  2008.0
# 3     4808              Warriors Orochi 2 (JP sales)      PS2  2008.0
# 4    13925                    Don Bradman Cricket 14     XOne  2015.0
# ..     ...                                       ...      ...     ...
# 548   4143                           SimCity Creator      Wii  2008.0
# 549  14462                             Freaky Flyers       XB  2003.0
# 550   7513                                Frogger 3D      3DS  2011.0
# 551    872           Tom Clancy's Rainbow Six: Vegas     X360  2006.0
# 552  16389                          TrackMania Turbo       PC  2016.0
#
#           Genre                     Publisher  NA_Sales  JP_Sales
# ...

# %%
df2 = df.replace({'Year' : np.nan}, '1234')
df2.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       4
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
qwe = SimpleImputer(strategy='mean', missing_values=np.nan)
qwe = qwe.fit(df1[['Year']])
df1['Year'] = qwe.transform(df1[['Year']])
df1.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       4
# NA_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.sort_values(by='Genre', ascending=False)
# Out:
#       Rank                                   Name Platform    Year     Genre
# 516  13179      Yu-Gi-Oh! World Championship 2007       DS  2007.0  Strategy  \
# 405  15029            Stronghold Crusader Extreme       PC  2008.0  Strategy
# 38    2338  Pokemon Card GB2: Here Comes Team GR!       GB  2001.0  Strategy
# 475  13704                                 XCOM 2      PS4  2016.0  Strategy
# 179   6643    A. IV Evolution: A Ressha de Ikou 4       PS  1994.0  Strategy
# ..     ...                                    ...      ...     ...       ...
# 238   9421                    Tomb Raider: Legend       XB  2006.0    Action
# 440   5045                            MediEvil II       PS  1999.0    Action
# 241  12593           Summon Night 6: Lost Borders      PSV  2016.0    Action
# 248  16288   Root Double: Before Crime After Days     X360  2012.0    Action
# 552  16389                       TrackMania Turbo       PC  2016.0    Action
#
# ...

# %%
df.to_csv('df.csv')
df1.to_csv('df1.csv')
df2.to_csv('df2.csv')
